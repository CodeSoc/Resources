# %%
import time
import random
from IPython import display

class hideNseek:
    def __init__(self):
        self.A = {"K":" ","L":" ","S":" ","B":" ","D":" ","F":" ","C":" ","G":" ","R":" "}
        self.B = {"K":" ","L":" ","S":" ","B":" ","D":" ","F":" ","C":" ","G":" ","R":" ","O":"H"}
        self.path = {"OF":" ","FS":" ","SL":" ","LK":" ","KC":" ","CB":" ","CR":" ","CG":" ","FD":" ","KD":" ","KK":" "}
        self.pathSet = {frozenset(("O","F")):["OF"],frozenset(("S","F")):["FS"],frozenset(("S","L")):["SL"],frozenset(("L","K")):["LK"],frozenset(("F","D")):["FD"],frozenset(("K","C")):["KK","KC"],frozenset(("D","K")):["KK","KD"],frozenset(("B","C")):["CB"],frozenset(("R","C")):["CR"],frozenset(("G","C")):["CG"]}
        self.moveDict = {'O':('F'),'F':('S','D'),'S':('L','F'),'L':('S','K'),'D':('F','K'),'K':('L','D','C'),'C':('K','B','R','G'),'B':('C'),'R':('C'),'G':('C')}
        self.rooms = ["K","L","S","B","D","F","C","G","R","O"]
        self.hider = random.randint(0,8)
        self.seeker = 9
        self.t = 0
        self.A[self.rooms[self.hider]] = "B"
        self.footprint = "."

    def bartSays(self,msg):
        print("                 ,  , \n                / \\/ \\,\'| _ \n               ,\'    \'  ,\' |,| \n              ,\'           \' |,\'| \n             ,\'                 ;\'| _ \n            ,\'                    \'\' | \n           ,\'                        ;-, \n          (___                        / \n        ,\'    `.  ___               ,\' \n       :       ,`\'   `-.           /            ..\""+msg+"\"\n       |-._ o /         \         /          ...\n      (    `-(           )       /        ...\n     ,\'`.     \      o  /      ,\'      ...\n    /    `     `.     ,\'      / \n   (             `\"\"\"\'       / \n    `._                     / \n       `--.______        \'\"`. \n          \__,__,`---._   \'`; \n               ))`-^--\')`,-\' \n             ,\',_____,\'  | \n             \_          `). \n              `.      _,\'  `\\ \n               /`-._,-\'      \\")
        print("Credits : hrr @ http://www.chris.com/ascii/index.php?art=cartoons/simpsons")

    def homerSays(self,msg):
        print("               ,---. \n            ,.\'-.   \ \n           ( ( ,\'\"\"\"\"\"-. \n           `,X          `. \n           /` `           `._ \n          (            ,   ,_\ \n          |          ,---.,\'o `. \n          |         / o   \     ) \n           \ ,.    (      .____,               ..\""+msg+"\"\n            \| \    \____,\'     \           ...\n          \'`'\  \        _,____,\'        ...\n          \  ,--      ,-\'     \       ...\n            ( C     ,\'         \ \n             `--\'  .\'           | \n               |   |        ___| \n             __|    \  ____- ,-\'_ \n            / `L     `._  _,\'  \' `. \n           /    `--.._  `\',.   _\  ` \n           `-.       /\  | `. ( ,\  \ \n          _/  `-._  /  \ |--\'  (     \ \n         \'  `-.   `\'    \/\`.   `.    ) \n               \           \ `.  |    | \n")
        print("Credits : hrr @ http://www.chris.com/ascii/index.php?art=cartoons/simpsons")
    
    def homerHappy(self,msg):
        print("               ,---. \n            ,.\'-.   \ \n           ( ( ,\'\"\"\"\"\"-. \n           `,X          `. \n           /` `           `._ \n          (            ,   ,_\ \n          |          ,---.,\'o `. \n          |         / o   \     ) \n           \ ,.    (      .____,               ..\""+msg+"\"\n            \| \    \____,\'     \           ...\n          \'`'\  \        _,____,\'        ...\n          \  ,--      ,-\'     \       ...\n            ( C     ,\'         \ \n             `--\'  .\'   ________| \n               |   |   |_|_|_|_| \n             __|    \        ,-\'_ \n            / `L     `._  _,\'  \' `. \n           /    `--.._  `\',.   _\  ` \n           `-.       /\  | `. ( ,\  \ \n          _/  `-._  /  \ |--\'  (     \ \n         \'  `-.   `\'    \/\`.   `.    ) \n               \           \ `.  |    | \n")
    
    def homerAngry(self,msg):
        print("                                                     ___,------, \n             _,--.---.                         __,--\'         / \n           ,\' _,\'_`._ \                    _,-\'           ___,| \n          ;--\'       `^-.                ,\'        __,---\'   || \n        ,\'               \             ,\'      _,-\'          || \n       /                  \         _,\'     ,-\'              || \n      :                    .      ,\'     _,\'                 |: \n      |                    :     `.    ,\'                    |: \n      |           _,-      |       `-,\'                      :: \n     ,\'____ ,  ,-\'  `.   , |,         `.                     : \ \n     ,\'    `-,\'       ) / \/ \          \                     : :\n     |      _\   o _,-\'    \'-.           `.                    \ \ \n      `o_,-\'  `-,-\' ____   ,` )-.______,\'  `.                   : : \n       \-\    _,---\'    `-. -\'.\  `.  /     `.                  \  \ \n        / `--\'             `.   \   \:        \                  \,.\          .."+msg+"\n       (              ____,  \  |    \\        \                 :\ \\         ...\n        )         _,-\'    `   | |    | \        \                 \\_\\     ...\n       /      _,-\'            | |   ,\'-`._      _\                 \,' ...\n       `-----\' |`-.           ;/   (__ ,\' `-. _;-\'`\           _,--\' \n     ,\'        |   `._     _,\' \-._/  Y    ,-\'      \      _,-' \n    /        _ |      `---\'    :,-|   |    `     _,-\'\_,--\'   \ \n   :          `|       \`-._   /  |   \'     `.,-\' `._`         \ \n   |           _\_    _,\/ _,-'|                     `-._       \ \n   :   ,-         `.-\'_,--\'    \                         `       \ \n   | ,\'           ,--\'      _,--\           _,                    : \n    )         .    \___,---\'   ) `-.____,--\'                      | \n   _\    .     `    ||        :            \                      ; \n ,\'  \    `.    )--\' ;        |             `-.                  / \n|     \     ;--^._,-\'         |                `-._            _/_\ \n\    ,\'`---\'                  |                    `--._____,-\'_\'  \ \n \_,\'                         `._                          _,-\'     ` \n                           ,-\'  `---.___           __,---\' \n                          ,\'             `---------\' \n                        ,\' \n")
        print("Credits : hrr @ http://www.chris.com/ascii/index.php?art=cartoons/simpsons")
    
    def homerDOH(self,msg):
        print("                       _ ,___,-\'\",-=-.\n           __,-- _ _,-\'_)_  (\"\"`\'-._\ `. \n        _,\'  __ |,\' ,-\' __)  ,-     /. | \n      ,\'_,--\'   |     -\'  _)/         `\ \n    ,\',\'      ,\'       ,-\'_,`           : \n    ,\'     ,-\'       ,(,-(              : \n         ,\'       ,-' ,    _            ; \n        /        ,-._/`---\'            / \n       /        (____)(----. )       ,\' \n      /         (      `.__,     /\ /, \n     :           ;-.___         /__\/| \n     |         ,\'      `--.      -,\ | \n     :        /            \    .__/       ..."+msg+"\n      \      (__            \    |_     ...\n       \       ,`-, *       /   _|,\ ...\n        \    ,\'   `-.     ,\'_,-\'    \ \n       (_\,-\'    ,\'\")--,\'-\'       __\ \n        \       /  // ,\'|      ,--\'  `-. \n         `-.    `-/ \\\'  |   _,\'         `.\n             `-._ /      `--\'/             \ \n              ,\'           |              \ \n              /             |               \ \n           ,-\'              |               / \n          /                 |             -\' ")
        print("Credits : hrr @ http://www.chris.com/ascii/index.php?art=cartoons/simpsons")
    
    def printMap(self):
        i=self.t
        A = self.A
        B = self.B
        path = self.path
        l = (" "*12+"|"+"-"*13+"|"+"-"*4+"|"+"-"*7+"|"+"\n"+" "*12+"|"+" "*13+"|"+" "*4+"|"+" "*7+"|"+"\n"+"|"+"-"*7+"  "+"-"*2+"|"+" "*13+"|"+" "*1+A["B"]+B["B"]+" "*1+"|"+" "*2+A["R"]+B["R"]+" "*3+"--|"+"\n"+"|"+" "*5+path["LK"]*11+A["K"]+B["K"]+" "*7+"|-"+" "+path["CB"]+"-|--"+" "+path["CR"]+" "*5+"|"+"\n"+"|"+" "*4+A["L"]+B["L"]+" "*5+"|"+" "*5+path["KK"]*5+path["KC"]*8+path["CR"]*5+" "*5+"|"+"\n"+"|"+" "*5+path["SL"]+" "*5+"|"+" "*9+path["KD"]+" "*3+"|"+" "*2+A["C"]+B["C"]+" "*2+"|"+"-"*7+"|"+"\n"+"|"+"-"*4+" "+path["SL"]+" "+"-"*4+"|"+"-"*9+path["KD"]+" "+"-"*3+"|"+" "*2+path["CG"]*7+" "*4+"|"+"\n"+"|"+" "*5+path["SL"]+" "*5+"|"+" "*4+"|"+" "*4+path["KD"]+" "*4+"|"+"-"*8+path["CG"]+" "+"-"*3+"|"+"\n"+"|"+" "*5+path["SL"]+" "*5+"|"+" "*4+"|"+" "*4+path["KD"]+" "*4+"|"+" "*8+path["CG"]+" "*4+"|"+"\n"+"|"+" "*4+A["S"]+B["S"]+path["FS"]*7+A["F"]+B["F"]+" "*1+"|"+" "*3+A["D"]+B["D"]+" "*4+"|"+" "*8+path["CG"]+" "*4+"|"+"\n"+"|"+" "*14+path["OF"]+path["FD"]*7+" "*4+"|"+" "*5+A["G"]+B["G"]+path["CG"]*2+" "*4+"|"+"\n"+"|"+"-"*11+"|"+"  "+path["OF"]+" "+"|"+"-"*9+"|"+" "*13+"|"+"\n"+""+" "*15+path["OF"]+" "*11+"|"+" "*13+"|"+"\n"+""+" "*15+B["O"]+" "*11+"|"+"-"*13+"|"+"\n"+""+" "*42+""+"\n"+""+" "*13+"time = "+str(i)+" "*13+"")
        print(l)
    
    def intro(self,sec):
        self.homerSays(" OOOH, TIME FOR THE BUFFET. NOW WHERE DID I PUT MY TICKET?! ")
        time.sleep(sec)
        display.clear_output(wait=True)
        self.bartSays(" HEY HOMER, IS THIS YOUR TICKET? IF YOU WANT IT, YOU'VE GOT TO FIND ME FIRST ")
        time.sleep(sec)
        display.clear_output(wait=True)
        self.printMap()
        self.homerAngry(" WHY YOU LITTLE.... I'LL CATCH YOU")
        time.sleep(sec+2)
    
    def runAuto(self,Tmax,footprint):
        while(not self.hider == self.seeker):
            self.t =self.t+1
            if self.t>Tmax:
                display.clear_output(wait=True)
                self.printMap()
                self.homerSays("AWWW....I GIVE UP!!")
                break
            else:
                display.clear_output(wait=True)
                self.B[self.rooms[self.seeker]] = footprint
                temp = random.choice(self.moveDict.get(self.rooms[self.seeker]))
                self.B[temp] = "H"
                init = self.rooms[self.seeker]
                final = temp
                for a in self.pathSet.get(frozenset((self.rooms[self.seeker],temp))):
                    self.path[a]=footprint
                self.seeker = self.rooms.index(temp)
                self.printMap()
                if self.t > 1:
                    self.homerDOH("DOH!!")
                time.sleep(1)
        if self.hider == self.seeker:
            display.clear_output(wait=True)
            self.printMap()
            self.homerHappy("FOUND YOU!!")
        print ("           -GAME OVER-               ")

# %%
H=hideNseek()
H.intro(3)
H.runAuto(40,".")
# Out:
#             |-------------|----|-------|
#             |             |    |       |
# |-------  --|             | BH |   .   --|
# |     ........... .       |- .-|-- .     |
# |     .     |     ..................     |
# |     .     |         .   |   .  |-------|
# |---- . ----|---------. ---|  .......    |
# |     .     |    |    .    |--------. ---|
# |     .     |    |    .    |        .    |
# |     ........ . |    .    |        .    |
# |              ........    |      ...    |
# |-----------|  . |---------|             |
#                .           |             |
#                .           |-------------|
#
#              time = 36
#                ,---.
#             ,.'-.   \
#            ( ( ,'"""""-.
#            `,X          `.
#            /` `           `._
#           (            ,   ,_\
#           |          ,---.,'o `.
#           |         / o   \     )
#            \ ,.    (      .____,               .."FOUND YOU!!"
# ...
